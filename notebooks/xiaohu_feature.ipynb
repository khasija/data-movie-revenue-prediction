# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import xlim
import numpy as np

# %% [markdown]
# # Import data

# %%
# Import data 'AllMoviesDetailsCleaned'

path = '/home/abeljiang2/code/final_project/data-movie-revenue-prediction/data/'
file_name = 'AllMoviesDetailsCleaned.csv'
data_details = pd.read_csv(f"{path}{file_name}", delimiter=';')
data_details.head()
# Out:
# /tmp/ipykernel_7357/1478768578.py:5: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_details = pd.read_csv(f"{path}{file_name}", delimiter=';')
#    id   budget                 genres    imdb_id original_language  \
# 0   2        0            Drama|Crime  tt0094675                fi
# 1   3        0           Drama|Comedy  tt0092149                fi
# 2   5  4000000           Crime|Comedy  tt0113101                en
# 3   6        0  Action|Thriller|Crime  tt0107286                en
# 4   8    42000            Documentary  tt0825671                en
#
#                      original_title  \
# 0                             Ariel
# 1              Varjoja paratiisissa
# 2                        Four Rooms
# 3                    Judgment Night
# 4  Life in Loops (A Megacities RMX)
#
#                                             overview popularity  \
# 0  Taisto Kasurinen is a Finnish coal miner whose...   0.823904
# ...

# %%
data_details.shape
# Out:
# (329044, 22)

# %%
# Import data 'AllMoviesCastingRaw'

path = '/home/abeljiang2/code/final_project/data-movie-revenue-prediction/data/'
file_name = 'AllMoviesCastingRaw.csv'
data_casting = pd.read_csv(f"{path}{file_name}", delimiter=';')
data_casting.head()
# Out:
#    id      actor1_name  actor1_gender       actor2_name  actor2_gender  \
# 0   2      Turo Pajala              0  Susanna Haavisto            0.0
# 1   3  Matti Pellonpää              2      Kati Outinen            1.0
# 2   5         Tim Roth              2  Antonio Banderas            2.0
# 3   6   Emilio Estevez              2  Cuba Gooding Jr.            2.0
# 4   8             none              0              none            0.0
#
#         actor3_name  actor3_gender   actor4_name  actor4_gender   actor5_name  \
# 0   Matti Pellonpää              2  Eetu Hilkamo              0          none
# 1  Sakari Kuosmanen              2  Esko Nikkari              2  Kylli Köngäs
# 2    Jennifer Beals              1       Madonna              1  Marisa Tomei
# 3       Denis Leary              2  Jeremy Piven              2  Peter Greene
# 4              none              0          none              0          none
#
#    actor5_gender  actor_number    director_name  director_gender  \
# ...

# %%
data_casting.shape
# Out:
# (329044, 19)

# %% [markdown]
# # Preprocessing data

# %%
data_join = data_details.join(data_casting, on = 'id', how = 'outer', lsuffix='_left', rsuffix='_right').drop(columns=['id_left','id_right'])
data_join.columns
# Out:
# Index(['id', 'budget', 'genres', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'production_companies_number',
#        'production_countries_number', 'spoken_languages_number', 'actor1_name',
#        'actor1_gender', 'actor2_name', 'actor2_gender', 'actor3_name',
#        'actor3_gender', 'actor4_name', 'actor4_gender', 'actor5_name',
#        'actor5_gender', 'actor_number', 'director_name', 'director_gender',
#        'director_number', 'producer_name', 'producer_number', 'screeplay_name',
#        'editor_name'],
#       dtype='object')

# %%
data_join.shape
# Out:
# (446696, 40)

# %%
data_join.describe()
# Out:
#                   id        budget       revenue        runtime  \
# count  446696.000000  3.290440e+05  3.290440e+05  292252.000000
# mean   226307.384293  6.129073e+05  1.533838e+06      60.406813
# std    133261.220608  6.845307e+06  2.401891e+07     142.502210
# min         0.000000  0.000000e+00 -1.200000e+01       0.000000
# 25%    111673.750000  0.000000e+00  0.000000e+00       5.000000
# 50%    223347.500000  0.000000e+00  0.000000e+00      71.000000
# 75%    335913.250000  0.000000e+00  0.000000e+00      94.000000
# max    469219.000000  6.000000e+08  2.781506e+09   51420.000000
#
#         vote_average     vote_count  production_companies_number  \
# count  329044.000000  329044.000000                 329044.00000
# mean        2.374474      14.211270                      0.59475
# std         3.126254     166.443851                      1.03807
# min         0.000000       0.000000                      0.00000
# ...

# %%
data_join_valid = data_join[data_join['revenue']>0]
data_join_valid.head()
# Out:
#      id      budget                            genres    imdb_id  \
# 2.0   5   4000000.0                      Crime|Comedy  tt0113101
# 3.0   6         0.0             Action|Thriller|Crime  tt0107286
# 6.0  11  11000000.0  Adventure|Action|Science Fiction  tt0076759
# 7.0  12  94000000.0                  Animation|Family  tt0266543
# 8.0  13  55000000.0              Comedy|Drama|Romance  tt0109830
#
#     original_language  original_title  \
# 2.0                en      Four Rooms
# 3.0                en  Judgment Night
# 6.0                en       Star Wars
# 7.0                en    Finding Nemo
# 8.0                en    Forrest Gump
#
#                                               overview popularity  \
# 2.0  It's Ted the Bellhop's first night on the job....      1.698
# 3.0  While racing to a boxing match, Frank, Mike, J...    1.32287
# 6.0  Princess Leia is captured and held hostage by ...  10.492614
# 7.0  Nemo, an adventurous young clownfish, is unexp...   9.915573
# ...

# %%
data_join_valid.shape
# Out:
# (8689, 40)

# %%
data_join_valid.isnull().sum().sort_values(ascending=False)
# Out:
# tagline                        2401
# editor_name                     671
# actor3_gender                   671
# actor2_gender                   671
# actor2_name                     671
# actor1_gender                   671
# actor1_name                     671
# actor4_name                     671
# actor4_gender                   671
# actor5_name                     671
# actor5_gender                   671
# actor_number                    671
# director_name                   671
# actor3_name                     671
# director_gender                 671
# director_number                 671
# producer_name                   671
# producer_number                 671
# screeplay_name                  671
# imdb_id                         349
# genres                          293
# overview                        273
# runtime                         158
# spoken_languages                115
# release_date                    104
# status                            5
# ...
