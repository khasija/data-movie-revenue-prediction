# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle

from python_files.data import GetData
from python_files.basic_preprocessing import BasicPreprocessing
from python_files.preprocessing import Advancedprocessing

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
clf_xgb = pickle.load(open('xgboost.sav', 'rb'))
# Out:
# /home/sourav/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
test_data = GetData().get_data()['kaggle_challenge_test']
test_data.head()
# Out:
#      imdb_id       id     budget             genres original_language  \
# 0  tt0005078  70368.0    17311.0              Drama                en
# 1  tt0009369  54242.0   250000.0       Comedy|Drama                en
# 2  tt0013140  35227.0  1100000.0              Drama                en
# 3  tt0014429  22596.0        0.0     Comedy|Romance                en
# 4  tt0015624   3060.0   245000.0  Drama|Romance|War                en
#
#    original_title                                           overview  \
# 0       The Cheat  A venal, spoiled stockbroker's wife impulsivel...
# 1          Mickey  Mickey, an orphan who has been brought up in a...
# 2   Foolish Wives  Actor / writer / director Erich von Stroheim s...
# 3    Safety Last!  When a store clerk organizes a contest to clim...
# 4  The Big Parade  The story of an idle rich boy who joins the US...
#
#                    production_companies      production_countries  \
# 0   Jesse L. Lasky Feature Play Company  United States of America
# 1    Mabel Normand Feature Film Company  United States of America
# 2  Universal Film Manufacturing Company  United States of America
# 3                     Hal Roach Studios  United States of America
# 4             Metro-Goldwyn-Mayer (MGM)  United States of America
#
#   release_date  ...    status  tagline           title vote_average  \
# 0   13/12/1915  ...  Released      NaN       The Cheat          4.8
# 1   01/08/1918  ...  Released      NaN          Mickey          7.5
# 2   11/01/1922  ...  Released      NaN   Foolish Wives          6.3
# 3   01/04/1923  ...  Released      NaN    Safety Last!          7.7
# 4   05/11/1925  ...  Released      NaN  The Big Parade          7.0
#
#   vote_count production_companies_number  production_countries_number  \
# 0       11.0                         1.0                          1.0
# 1        4.0                         1.0                          1.0
# 2        9.0                         1.0                          1.0
# 3       70.0                         1.0                          1.0
# 4       21.0                         1.0                          1.0
#
#    spoken_languages_number  belongs_to_collection  popularity
# 0                      0.0                    NaN    0.680407
# 1                      1.0                    NaN    0.211008
# 2                      1.0                    NaN    0.838095
# 3                      1.0                    NaN    4.394823
# 4                      0.0                    NaN    2.084627
#
# [5 rows x 23 columns]

# %%
df_test = test_data.copy()

# %%
X = df_test.drop(columns = ['revenue'])
y = df_test['revenue']

# %%
X = BasicPreprocessing.apply(X, train_set = False)
X.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'belongs_to_collection'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_16540/2469640644.py in <module>
# ----> 1 X = BasicPreprocessing.apply(X, train_set = False)
#       2 X.head()
#
# ~/code/Urus1201/data-movie-revenue-prediction/python_files/basic_preprocessing.py in apply(data, train_set)
#      25
#      26         # 3.add column with 1 if movie belongs to any collection and 0 if it does not belong to any collection
# ---> 27         df['collection'] = df['belongs_to_collection'].apply(lambda x: 0 if type(x) == float and pd.isna(x) else 1)
#      28
#      29         # 4. Deal with missing Values
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'belongs_to_collection'

# %%
X =
