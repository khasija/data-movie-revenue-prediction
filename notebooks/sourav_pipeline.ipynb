# %% [markdown]
# ## Import Module

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from sklearn.pipeline import Pipeline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from python_files.fetch_missing_data import fetch_missing_data
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.dummy import DummyRegressor
from python_files.data import GetData
from python_files.basic_preprocessing import BasicPreprocessing
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %% [markdown]
# ## Clean the data

# %%
data = GetData().get_data()['AllMoviesDetailsCleaned']
data.head()
# Out:
#    id   budget                 genres    imdb_id original_language  \
# 0   2        0            Drama|Crime  tt0094675                fi
# 1   3        0           Drama|Comedy  tt0092149                fi
# 2   5  4000000           Crime|Comedy  tt0113101                en
# 3   6        0  Action|Thriller|Crime  tt0107286                en
# 4   8    42000            Documentary  tt0825671                en
#
#                      original_title  \
# 0                             Ariel
# 1              Varjoja paratiisissa
# 2                        Four Rooms
# 3                    Judgment Night
# 4  Life in Loops (A Megacities RMX)
#
#                                             overview  popularity  \
# 0  Taisto Kasurinen is a Finnish coal miner whose...         NaN
# 1  An episode in the life of Nikander, a garbage ...         NaN
# 2  It's Ted the Bellhop's first night on the job....         NaN
# 3  While racing to a boxing match, Frank, Mike, J...         NaN
# 4  Timo Novotny labels his new project an experim...         NaN
#
#           production_companies      production_countries  ...  \
# 0  Villealfa Filmproduction Oy                   Finland  ...
# 1  Villealfa Filmproduction Oy                   Finland  ...
# 2                Miramax Films  United States of America  ...
# 3           Universal Pictures                     Japan  ...
# 4                      inLoops                   Austria  ...
#
#   spoken_languages    status  \
# 0            suomi  Released
# 1          English  Released
# 2          English  Released
# 3          English  Released
# 4          English  Released
#
#                                              tagline  \
# 0                                                NaN
# 1                                                NaN
# 2  Twelve outrageous guests. Four scandalous requ...
# 3     Don't move. Don't whisper. Don't even breathe.
# 4                                A Megacities remix.
#
#                               title vote_average vote_count  \
# 0                             Ariel          7.1         40
# 1               Shadows in Paradise          7.0         32
# 2                        Four Rooms          6.5        485
# 3                    Judgment Night          6.5         69
# 4  Life in Loops (A Megacities RMX)          6.4          4
#
#   production_companies_number  production_countries_number  \
# 0                           2                            1
# 1                           1                            1
# 2                           2                            1
# 3                           3                            2
# 4                           1                            1
#
#    spoken_languages_number  belongs_to_collection
# 0                        2                    NaN
# 1                        3                    NaN
# 2                        1                    NaN
# 3                        1                    NaN
# 4                        5                    NaN
#
# [5 rows x 23 columns]

# %%
data.shape
# Out:
# (329074, 23)

# %%
pd.read_csv('../data/AllMoviesDetailsCleaned.csv')
# Out:
# /tmp/ipykernel_27731/2503657910.py:1: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('../data/AllMoviesDetailsCleaned.csv')
#             id   budget                        genres    imdb_id  \
# 0            2        0                   Drama|Crime  tt0094675
# 1            3        0                  Drama|Comedy  tt0092149
# 2            5  4000000                  Crime|Comedy  tt0113101
# 3            6        0         Action|Thriller|Crime  tt0107286
# 4            8    42000                   Documentary  tt0825671
# ...        ...      ...                           ...        ...
# 329069  469215        0  Documentary|History|TV Movie  tt5430190
# 329070  469216        0                           NaN        NaN
# 329071  469217        0                  Drama|Comedy        NaN
# 329072  469218        0                  Drama|Comedy  tt6391664
# 329073  469219        0                         Drama  tt6413160
#
#        original_language                                original_title  \
# 0                     fi                                         Ariel
# 1                     fi                          Varjoja paratiisissa
# 2                     en                                    Four Rooms
# 3                     en                                Judgment Night
# 4                     en              Life in Loops (A Megacities RMX)
# ...                  ...                                           ...
# 329069                en                           The Day Hitler Died
# 329070                de  Mobb Deep - Life of the Infamous: The Videos
# 329071                en                                        #idiot
# 329072                en                              Conspiracy P.I.E
# 329073                en                                        Chance
#
#                                                  overview  popularity  \
# 0       Taisto Kasurinen is a Finnish coal miner whose...         NaN
# 1       An episode in the life of Nikander, a garbage ...         NaN
# 2       It's Ted the Bellhop's first night on the job....         NaN
# 3       While racing to a boxing match, Frank, Mike, J...         NaN
# 4       Timo Novotny labels his new project an experim...         NaN
# ...                                                   ...         ...
# 329069  The story of Hitler’s final hours told by peop...         NaN
# 329070                                                NaN         NaN
# 329071  In the modern day pursuit of fame and fortune,...         NaN
# 329072  Director Levi A. Taylor invites you on a nosta...         NaN
# 329073  A homeless man is given a second chance at lif...         NaN
#
#                production_companies      production_countries  ...  \
# 0       Villealfa Filmproduction Oy                   Finland  ...
# 1       Villealfa Filmproduction Oy                   Finland  ...
# 2                     Miramax Films  United States of America  ...
# 3                Universal Pictures                     Japan  ...
# 4                           inLoops                   Austria  ...
# ...                             ...                       ...  ...
# 329069              History Channel  United States of America  ...
# 329070     Sony Music Entertainmant  United States of America  ...
# 329071                         none                  Malaysia  ...
# 329072                         none  United States of America  ...
# 329073                         none  United States of America  ...
#
#        spoken_languages    status  \
# 0                 suomi  Released
# 1               English  Released
# 2               English  Released
# 3               English  Released
# 4               English  Released
# ...                 ...       ...
# 329069          Deutsch  Released
# 329070          English  Released
# 329071          English  Released
# 329072          English  Released
# 329073          English  Released
#
#                                                   tagline  \
# 0                                                     NaN
# 1                                                     NaN
# 2       Twelve outrageous guests. Four scandalous requ...
# 3          Don't move. Don't whisper. Don't even breathe.
# 4                                     A Megacities remix.
# ...                                                   ...
# 329069                                   April 30th, 1945
# 329070                                                NaN
# 329071                                                NaN
# 329072                                                NaN
# 329073                                                NaN
#
#                                                title vote_average vote_count  \
# 0                                              Ariel          7.1         40
# 1                                Shadows in Paradise          7.0         32
# 2                                         Four Rooms          6.5        485
# 3                                     Judgment Night          6.5         69
# 4                   Life in Loops (A Megacities RMX)          6.4          4
# ...                                              ...          ...        ...
# 329069                           The Day Hitler Died          7.0          1
# 329070  Mobb Deep - Life of the Infamous: The Videos          9.0          1
# 329071                                        #idiot          0.0          0
# 329072                              Conspiracy P.I.E          0.0          0
# 329073                                        Chance          0.0          0
#
#        production_companies_number  production_countries_number  \
# 0                                2                            1
# 1                                1                            1
# 2                                2                            1
# 3                                3                            2
# 4                                1                            1
# ...                            ...                          ...
# 329069                           1                            1
# 329070                           1                            1
# 329071                           0                            1
# 329072                           0                            1
# 329073                           0                            1
#
#         spoken_languages_number  belongs_to_collection
# 0                             2                    NaN
# 1                             3                    NaN
# 2                             1                    NaN
# 3                             1                    NaN
# 4                             5                    NaN
# ...                         ...                    ...
# 329069                        2                    NaN
# 329070                        1                    NaN
# 329071                        1                    NaN
# 329072                        1                    NaN
# 329073                        1                    NaN
#
# [329074 rows x 23 columns]

# %% [markdown]
# ### Apply basic preprocessing

# %%
df = BasicPreprocessing.apply(data)
df.head()
# Out:
#    id    budget                            genres original_language  \
# 2   5   4000000                      Crime|Comedy                en
# 5   9   4000000                             Drama                de
# 6  11  11000000  Adventure|Action|Science Fiction                en
# 7  12  94000000                  Animation|Family                en
# 8  13  55000000              Comedy|Drama|Romance                en
#
#       original_title     production_companies      production_countries  \
# 2         Four Rooms            Miramax Films  United States of America
# 5  Sonntag im August                     none                   Germany
# 6          Star Wars                Lucasfilm  United States of America
# 7       Finding Nemo  Pixar Animation Studios  United States of America
# 8       Forrest Gump       Paramount Pictures  United States of America
#
#   release_date    revenue  runtime             title  vote_average  \
# 2   25/12/1995    4300000     98.0        Four Rooms           6.5
# 5     2/9/2004    4257354     15.0  Sunday in August           5.7
# 6   25/05/1977  775398007    121.0         Star Wars           8.0
# 7   30/05/2003  940335536    100.0      Finding Nemo           7.6
# 8     6/7/1994  677945399    142.0      Forrest Gump           8.2
#
#    vote_count  production_companies_number  production_countries_number  \
# 2         485                            2                            1
# 5        2256                            0                            1
# 6        6168                            2                            1
# 7        5531                            1                            1
# 8        7204                            1                            1
#
#    spoken_languages_number  collection
# 2                        1           1
# 5                        1           1
# 6                        1           1
# 7                        1           1
# 8                        1           1

# %%
df.columns
# Out:
# Index(['id', 'budget', 'genres', 'original_language', 'original_title',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'title', 'vote_average', 'vote_count',
#        'production_companies_number', 'production_countries_number',
#        'spoken_languages_number', 'collection'],
#       dtype='object')

# %%
df.shape
# Out:
# (8628, 17)

# %% [markdown]
# ### Impute the remaining missing values

# %%
df.isna().sum()
# Out:
# id                               0
# budget                           0
# genres                         209
# original_language                0
# original_title                   0
# production_companies             0
# production_countries             0
# release_date                     0
# revenue                          0
# runtime                         16
# title                            0
# vote_average                     0
# vote_count                       0
# production_companies_number      0
# production_countries_number      0
# spoken_languages_number          0
# collection                       0
# dtype: int64

# %% [markdown]
# Before imputing I need to split the data

# %% [markdown]
# ### Create `X_basic` that contains only numerical and categorical features.

# %%
df.dtypes
# Out:
# id                               int64
# budget                           int64
# genres                          object
# original_language               object
# original_title                  object
# production_companies            object
# production_countries            object
# release_date                    object
# revenue                          int64
# runtime                        float64
# title                           object
# vote_average                   float64
# vote_count                       int64
# production_companies_number      int64
# production_countries_number      int64
# spoken_languages_number          int64
# collection                       int64
# dtype: object

# %%
X_basic = df.drop(columns = ['revenue', 'release_date'])
y = df['revenue']

# %%
# Impute and scale numeric data
numeric_transformer = Pipeline(steps=[ 
    ('imputer', SimpleImputer(strategy= 'mean')),
    ('scaler', StandardScaler())])
 
# Convert categorical data to binary
categorical_transformer = Pipeline(steps=[
    ('encoder', OneHotEncoder(handle_unknown='ignore'))])

# %%
numeric_transformer.fit_transform(df[['runtime']])
# Out:
# array([[-1.78265107e-01],
#        [-2.80186882e+00],
#        [ 5.48757609e-01],
#        ...,
#        [-4.49200617e-16],
#        [ 1.87636431e+00],
#        [ 1.06222043e-01]])
