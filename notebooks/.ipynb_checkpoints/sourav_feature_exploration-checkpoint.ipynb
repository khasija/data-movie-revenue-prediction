# %% [markdown]
# ## Import Module

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Process Categorical Features

# %%
data = pd.read_csv('../data/AllMoviesDetailsCleaned.csv')
# Out:
# /tmp/ipykernel_3492/928083239.py:1: DtypeWarning: Columns (27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('../data/AllMoviesDetailsCleaned.csv')

# %%
df_movie = data.copy()
df_movie.head()
# Out:
#    id   budget                 genres    imdb_id original_language  \
# 0   2        0            Drama|Crime  tt0094675                fi
# 1   3        0           Drama|Comedy  tt0092149                fi
# 2   5  4000000           Crime|Comedy  tt0113101                en
# 3   6        0  Action|Thriller|Crime  tt0107286                en
# 4   8    42000            Documentary  tt0825671                en
#
#                      original_title  \
# 0                             Ariel
# 1              Varjoja paratiisissa
# 2                        Four Rooms
# 3                    Judgment Night
# 4  Life in Loops (A Megacities RMX)
#
#                                             overview  popularity  \
# 0  Taisto Kasurinen is a Finnish coal miner whose...         NaN
# 1  An episode in the life of Nikander, a garbage ...         NaN
# 2  It's Ted the Bellhop's first night on the job....         NaN
# 3  While racing to a boxing match, Frank, Mike, J...         NaN
# 4  Timo Novotny labels his new project an experim...         NaN
#
#           production_companies      production_countries  ...  \
# 0  Villealfa Filmproduction Oy                   Finland  ...
# 1  Villealfa Filmproduction Oy                   Finland  ...
# 2                Miramax Films  United States of America  ...
# 3           Universal Pictures                     Japan  ...
# 4                      inLoops                   Austria  ...
#
#   production_companies_number  production_countries_number  \
# 0                           2                            1
# 1                           1                            1
# 2                           2                            1
# 3                           3                            2
# 4                           1                            1
#
#    spoken_languages_number budget_new revenue_new popularity_new  \
# 0                        2        NaN         NaN            NaN
# 1                        3        NaN         NaN            NaN
# 2                        1        NaN         NaN            NaN
# 3                        1        NaN         NaN            NaN
# 4                        5        NaN         NaN            NaN
#
#   vote_average_new  vote_count_new  belongs_to_collection_x  \
# 0              NaN             NaN                      NaN
# 1              NaN             NaN                      NaN
# 2              NaN             NaN                      NaN
# 3              NaN             NaN                      NaN
# 4              NaN             NaN                      NaN
#
#    belongs_to_collection
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 29 columns]

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy= 'constant')

df_movie[['belongs_to_collection']] = pd.DataFrame(imputer.fit_transform(df_movie[['belongs_to_collection']]), columns = ['belongs_to_collection'])

# %%
df_movie['belongs_to_collection'].isna().value_counts()
# Out:
# True     324600
# False      4474
# Name: belongs_to_collection, dtype: int64

# %%
# add column with 1 if movie belongs to any collection and 0 if it does not belong to any collection
df_movie['collection'] = df_movie['belongs_to_collection'].apply(lambda x: 1 if x != 'missing_value' else 0)

sns.boxplot(x = 'collection', y = 'revenue', data = df_movie);

# %%
df_movie['collection'].value_counts()
# Out:
# 0    324600
# 1      4474
# Name: collection, dtype: int64

# %%
print(df_movie.groupby('collection')['revenue'].mean().apply(lambda x: format(x, ',.2f')))
# Out:
# collection
# 0     1,477,982.62
# 1    57,284,784.61
# Name: revenue, dtype: object

# %% [markdown]
# **Analysis:** The revenue is generally higher for movies that are part of a collection. We can use this binary collection variable for our model. ✌

# %%
df_movie.columns
# Out:
# Index(['id', 'budget', 'genres', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'production_companies_number',
#        'production_countries_number', 'spoken_languages_number', 'budget_new',
#        'revenue_new', 'popularity_new', 'vote_average_new', 'vote_count_new',
#        'belongs_to_collection_x', 'belongs_to_collection', 'collection',
#        'number_production_companies'],
#       dtype='object')

# %%
# Add column for existence of tag line
df_movie['tagline_exists'] = df_movie['tagline'].apply(lambda x: 1 if x != 0 else 0)

# %%
# Add column for length of tag line
df_movie['tagline'].fillna(0, inplace=True)
df_movie['tagline_length'] = df_movie['tagline'].apply(lambda x: len(x) if x != 0 else 0)

# %%
# Add column for length of title
df['title'].fillna(0, inplace=True)
df['title_length'] = df['title'].apply(lambda x: len(x) if x != 0 else 0)

# %%
df_cast = pd.read_csv('../data/AllMoviesCastingRaw.csv', delimiter=';')
df_cast.head()
# Out:
#    id      actor1_name  actor1_gender       actor2_name  actor2_gender  \
# 0   2      Turo Pajala              0  Susanna Haavisto            0.0
# 1   3  Matti Pellonpää              2      Kati Outinen            1.0
# 2   5         Tim Roth              2  Antonio Banderas            2.0
# 3   6   Emilio Estevez              2  Cuba Gooding Jr.            2.0
# 4   8             none              0              none            0.0
#
#         actor3_name  actor3_gender   actor4_name  actor4_gender   actor5_name  \
# 0   Matti Pellonpää              2  Eetu Hilkamo              0          none
# 1  Sakari Kuosmanen              2  Esko Nikkari              2  Kylli Köngäs
# 2    Jennifer Beals              1       Madonna              1  Marisa Tomei
# 3       Denis Leary              2  Jeremy Piven              2  Peter Greene
# 4              none              0          none              0          none
#
#    actor5_gender  actor_number    director_name  director_gender  \
# 0              0             4   Aki Kaurismäki              0.0
# 1              0             7   Aki Kaurismäki              0.0
# 2              1            24   Allison Anders              1.0
# 3              2            15  Stephen Hopkins              2.0
# 4              0             0     Timo Novotny              0.0
#
#    director_number    producer_name  producer_number     screeplay_name  \
# 0                1             none                0     Aki Kaurismäki
# 1                1  Mika Kaurismäki                1     Aki Kaurismäki
# 2                4  Lawrence Bender                1               none
# 3                1        Gene Levy                1       Lewis Colick
# 4                1     Timo Novotny                2  Michael Glawogger
#
#           editor_name
# 0        Raija Talvio
# 1        Raija Talvio
# 2  Margaret Goodspeed
# 3        Tim Wellburn
# 4        Timo Novotny

# %%
def count_actors(series):
    count_actor = 0
    for i in range(1,6):
        if series[f'actor{i}_name'] != 'none':
            count_actor += 1
    return count_actor

# %%
df_cast['count_actors'] = 'not counted'
df_cast.head()
# Out:
#    id actor1_name  actor1_gender actor2_name  actor2_gender actor3_name  \
# 0   4           4              4           4            4.0           4
# 1   5           5              5           5            5.0           5
# 2   5           5              5           5            5.0           5
# 3   5           5              5           5            5.0           5
# 4   0           0              0           0            0.0           0
#
#    actor3_gender actor4_name  actor4_gender actor5_name  actor5_gender  \
# 0              4           4              4           4              4
# 1              5           5              5           5              5
# 2              5           5              5           5              5
# 3              5           5              5           5              5
# 4              0           0              0           0              0
#
#    actor_number director_name  director_gender  director_number producer_name  \
# 0             4             4              4.0                4             4
# 1             5             5              5.0                5             5
# 2             5             5              5.0                5             5
# 3             5             5              5.0                5             5
# 4             0             0              0.0                0             0
#
#    producer_number screeplay_name editor_name count_actors
# 0                4              4           4  not counted
# 1                5              5           5  not counted
# 2                5              5           5  not counted
# 3                5              5           5  not counted
# 4                0              0           0  not counted

# %%
for idx, row in df_cast.iterrows():
    df_cast.loc[idx] = count_actors(row)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3492/2298792133.py in <module>
#       1 for idx, row in df_cast.iterrows():
# ----> 2     df_cast.loc[idx] = count_actors(row)
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     714
#     715         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716         iloc._setitem_with_indexer(indexer, value, self.name)
#     717
#     718     def _validate_key(self, key, axis: int):
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1689         if take_split_path:
#    1690             # We have to operate column-wise
# -> 1691             self._setitem_with_indexer_split_path(indexer, value, name)
#    1692         else:
#    1693             self._setitem_single_block(indexer, value, name)
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_with_indexer_split_path(self, indexer, value, name)
#    1782             # scalar value
#    1783             for loc in ilocs:
# -> 1784                 self._setitem_single_column(loc, value, pi)
#    1785
#    1786     def _setitem_with_indexer_2d_value(self, indexer, value):
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_single_column(self, loc, value, plane_indexer)
#    1888
#    1889             orig_values = ser._values
# -> 1890             ser._mgr = ser._mgr.setitem((pi,), value)
#    1891
#    1892             if ser._values is orig_values:
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/internals/managers.py in setitem(self, indexer, value)
#     335         For SingleBlockManager, this backs s[indexer] = value
#     336         """
# --> 337         return self.apply("setitem", indexer=indexer, value=value)
#     338
#     339     def putmask(self, mask, new, align: bool = True):
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     307                     raise
#     308                 continue
# --> 309             result_blocks = extend_blocks(applied, result_blocks)
#     310
#     311         if ignore_failures:
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/internals/blocks.py in extend_blocks(result, blocks)
#    2123     if blocks is None:
#    2124         blocks = []
# -> 2125     if isinstance(result, list):
#    2126         for r in result:
#    2127             if isinstance(r, list):
#
# KeyboardInterrupt:

# %%
df_cast

# %%
df_cast.loc[1]
# Out:
# id                                3
# actor1_name         Matti Pellonpää
# actor1_gender                     2
# actor2_name            Kati Outinen
# actor2_gender                   1.0
# actor3_name        Sakari Kuosmanen
# actor3_gender                     2
# actor4_name            Esko Nikkari
# actor4_gender                     2
# actor5_name            Kylli Köngäs
# actor5_gender                     0
# actor_number                      7
# director_name        Aki Kaurismäki
# director_gender                 0.0
# director_number                   1
# producer_name       Mika Kaurismäki
# producer_number                   1
# screeplay_name       Aki Kaurismäki
# editor_name            Raija Talvio
# Name: 1, dtype: object

# %%
df_cast.apply(count_actors)
# Out:
# > /tmp/ipykernel_3492/1877898420.py(3)count_actors()
#       2     import ipdb;ipdb.set_trace()
# ----> 3     count_actor = 0
#       4     for i in range(1,6):
#
# ipdb> series
# 0              2
# 1              3
# 2              5
# 3              6
# 4              8
#            ...
# 329039    469215
# 329040    469216
# 329041    469217
# 329042    469218
# 329043    469219
# Name: id, Length: 329044, dtype: int64
# ipdb> c
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3492/2551442914.py in <module>
# ----> 1 df_cast.apply(count_actors)
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8846             kwargs=kwargs,
#    8847         )
# -> 8848         return op.apply().__finalize__(self, method="apply")
#    8849
#    8850     def applymap(
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/apply.py in apply(self)
#     731             return self.apply_raw()
#     732
# --> 733         return self.apply_standard()
#     734
#     735     def agg(self):
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     855
#     856     def apply_standard(self):
# --> 857         results, res_index = self.apply_series_generator()
#     858
#     859         # wrap results
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     871             for i, v in enumerate(series_gen):
#     872                 # ignore SettingWithCopy here in case the user mutates
# --> 873                 results[i] = self.f(v)
#     874                 if isinstance(results[i], ABCSeries):
#     875                     # If we have a view on v, we need to make a copy because
#
# /tmp/ipykernel_3492/1877898420.py in count_actors(series)
#       1 def count_actors(series):
#       2     import ipdb;ipdb.set_trace()
# ----> 3     count_actor = 0
#       4     for i in range(1,6):
#       5         if series[f'actor{i}_name'] != 'none':
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     387                     raise KeyError(key) from err
#     388             self._check_indexing_error(key)
# --> 389             raise KeyError(key)
#     390         return super().get_loc(key, method=method, tolerance=tolerance)
#     391
#
# KeyError: 'actor1_name'

# %%
df_cast['actor_count'] =
